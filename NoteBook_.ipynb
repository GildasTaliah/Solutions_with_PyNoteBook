# %% [markdown]
# <a href="https://colab.research.google.com/github/GildasTaliah/Solutions_with_PyNoteBook/blob/main/NoteBook_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **NoteBook guide**
#
#
#    $$# Heading 1$$
#    $$## Subheading$$
#    $$# Heading2....$$
#
#
# ## Fonts Colour
# $$<font color='blue'>The color of this text is blue.</font>$$
#
#
# <font color='darkblue'>The color of this text is dark blue.</font>
# <font color='darkred'>The color of this text is dark red.</font>
# <font color='blue'>The color of this text is blue.</font>
#
#
# ## Block Quotes
#
# $$>$$
#
# > We stop growing when we stop learning - Gildas T.
#
# ## Horizontal Lines
# $$***$$
#
# ***
#
# ## Hyperlinks
#
# $$[link text](https://)$$
#
# [link: For Quantitative Finance on Wiki ](https://en.wikipedia.org/wiki/Quantitative_analysis_(finance))

# %% [markdown]
# # Images
# $$![link text](https://)$$
#
# ![link: Value Risk diagram](https://images.app.goo.gl/jPvMS5HMYRUTKsir6)
#
# ![DALL·E 2024-12-02 15.52.55 - A visually engaging image representing quantitative finance, featuring a dynamic stock market graph overlaying a background of financial data, algorit.webp](data:image/webp;base64,...)

# %% [markdown]
# # LaTex
#
# **\hat{\mu} = \frac{1}{n}\sum_{i=1}^{n} x_i** with $$ wraped around it.
#
# $$\hat{\mu} = \frac{1}{n}\sum_{i=1}^{n} x_i $$
#
#
# # Tables
# $$|To | buidl|$$ $$|-|-|$$ $$|a|table|$$
#
#
# |To|Build|
# |-|-|
# |a|table|
#
# # Programming code
#
# $$
# ```# This is formatted as code ```$$
#
# ```python
# def func(x):
#  return x**2
# ```
#
# ```R
# func <- function(x){return x**2}
# ```
#
# ```javascript
# console.log('Hello World!')
# ```
#
#
# # Magic Commands
#
# $$# Save notebook every 60 seconds
# %autosave 60$$
#
#
#
# $$# **%history** shows the history of the previously executed magic commands.$$
#
#
# $$# **%time** displays the time taken by a cell for execution.$$
#
# $$# **%matplotlib** inline allows you to plot charts inline within a notebook.$$
#
# $$# **%ls** lists the content of the current directory.$$
#
# $$# **%clear** and **%cls** command clear the output of the current cell.$$
#
# $$# **%env** allows you to list all environment variables as well as set the value of particular environment variables.$$
#
# $$# **%ls** lists the content of the current directory.$$
#
# $$# **%pip** enables one to list and install all available packages from Jupyter environment.$$
#
# $$# **%who** list all variables from the global scope.$$

# %%
import numpy as np

num_text = np.array(text)
type(num_text), num_text.dtype

pd.DataFrame(num_text)
# Out:
#                                                    0
# 0  label,text\npre_purchase,how's it going Arthur...

# %%
# !pip install torchmetrics
# !pip install torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchmetrics import Accuracy, Precision, Recall

# %%
# Load datasets
from torchvision import datasets
import torchvision.transforms as transforms

train_data = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_data = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())
# Out:
# ...
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 18.3MB/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 309kB/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 5.58MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 13.3MB/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
type(train_data)
# Out:
# torchvision.datasets.mnist.FashionMNIST
